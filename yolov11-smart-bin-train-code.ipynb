# %%
# !pip install "numpy<2.0" -q

# %%
import os
import shutil
import glob
import yaml
import torch
from tqdm import tqdm

# ==========================================
# 1. SETUP & INSTALL
# ==========================================
print("--- STEP 1: Setup ---")
# Install Ultralytics quietly
os.system('pip install ultralytics -q')
print("✅ Ultralytics installed.")

from ultralytics import YOLO

# Check GPU
if torch.cuda.is_available():
    print(f"✅ GPU Detected: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ WARNING: No GPU detected. Enable it in Session Options.")

# ==========================================
# 2. FIND & COPY DATASET
# ==========================================
print("\n--- STEP 2: Preparing Data ---")

# Define paths
INPUT_ROOT = '/kaggle/input'
WORKING_DIR = '/kaggle/working/my_dataset'

# Clean up previous runs
if os.path.exists(WORKING_DIR):
    shutil.rmtree(WORKING_DIR)

# 1. Search for data.yaml to find the dataset root
print("🔍 Searching for dataset folder...")
yaml_files = glob.glob(f"{INPUT_ROOT}/**/data.yaml", recursive=True)

if not yaml_files:
    print("❌ Error: Could not find 'data.yaml' in /kaggle/input.")
    print("Please check your 'Input' sidebar. Did you upload the dataset correctly?")
    raise FileNotFoundError("Dataset not found!")

# 2. Identify the Source Folder
src_yaml_path = yaml_files[0]
src_dataset_dir = os.path.dirname(src_yaml_path) # The folder containing data.yaml
print(f"✅ Found dataset at: {src_dataset_dir}")

# 3. Copy to Writable Directory (Required for YOLO caching & editing yaml)
print(f"📂 Copying data to {WORKING_DIR} (This may take a minute)...")
shutil.copytree(src_dataset_dir, WORKING_DIR)
print("✅ Copy Complete.")

# ==========================================
# 3. FIX DATA.YAML PATHS & CLASSES
# ==========================================
print("\n--- STEP 3: Fixing Config & Classes ---")

dest_yaml_path = os.path.join(WORKING_DIR, "data.yaml")

# 1. Load yaml
with open(dest_yaml_path, 'r') as f:
    data = yaml.safe_load(f)
    old_names = data['names']

# 2. FIX PATHS (Critical Step)
# We overwrite relative paths with ABSOLUTE paths to the new writable folder
data['path']  = WORKING_DIR 
data['train'] = "train/images"
data['val']   = "valid/images" # Roboflow uses 'valid', YOLO uses 'val'
data['test']  = "test/images"

# 3. Define Class Mapping
BIO_NAMES = ['biodegradable', 'cardboard', 'paper']
NON_BIO_NAMES = ['glass', 'metal', 'plastic', 'trash']

id_map = {}
print(f"Mapping from: {old_names}")

for idx, name in enumerate(old_names):
    clean_name = name.lower().strip()
    if clean_name in BIO_NAMES:
        id_map[idx] = 0 # Biodegradable
    else:
        id_map[idx] = 1 # Non-Biodegradable (Default)

# 4. Rewrite Label Files
label_files = glob.glob(f"{WORKING_DIR}/**/*.txt", recursive=True)
print(f"Processing {len(label_files)} label files...")

for file_path in tqdm(label_files):
    if file_path.endswith("classes.txt"): continue
    
    new_lines = []
    with open(file_path, 'r') as f:
        lines = f.readlines()
        
    for line in lines:
        parts = line.strip().split()
        if not parts: continue
        
        try:
            old_id = int(parts[0])
            if old_id in id_map:
                new_id = id_map[old_id]
                new_lines.append(f"{new_id} {' '.join(parts[1:])}\n")
        except ValueError:
            continue
            
    with open(file_path, 'w') as f:
        f.writelines(new_lines)

# 5. Update YAML with new Classes
data['nc'] = 2
data['names'] = ['Biodegradable', 'Non-Biodegradable']

with open(dest_yaml_path, 'w') as f:
    yaml.dump(data, f)

print("✅ Configuration Fixed!")

# ==========================================
# 4. START TRAINING
# ==========================================
print("\n--- STEP 4: Training YOLO11 ---")

PROJECT_DIR = '/kaggle/working/runs'
NAME = 'waste_detection'

model = YOLO('yolo11n.pt') 

results = model.train(
    data=dest_yaml_path, # Point to our fixed YAML
    epochs=50,          
    imgsz=640,
    batch=16,           
    project=PROJECT_DIR,
    name=NAME,
    patience=15,
    save=True,
    exist_ok=True
)

# ==========================================
# 5. ZIP RESULTS
# ==========================================
import shutil
from IPython.display import FileLink

print("\n--- STEP 5: Zipping Output ---")
output_folder = f"{PROJECT_DIR}/{NAME}"
zip_name = "YOLO_Results"
shutil.make_archive(zip_name, 'zip', output_folder)

print(f"✅ Zip created! Click below to download:")
display(FileLink(f"{zip_name}.zip"))
# Out:
# --- STEP 1: Setup ---
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# ✅ Ultralytics installed.
# ✅ GPU Detected: Tesla T4
#
# --- STEP 2: Preparing Data ---
# 🔍 Searching for dataset folder...
# ✅ Found dataset at: /kaggle/input/yolo-dataset
# 📂 Copying data to /kaggle/working/my_dataset (This may take a minute)...
# ✅ Copy Complete.
#
# --- STEP 3: Fixing Config & Classes ---
# Mapping from: ['BIODEGRADABLE', 'CARDBOARD', 'GLASS', 'METAL', 'PAPER', 'PLASTIC']
# Processing 17367 label files...
# 100%|██████████| 17367/17367 [00:01<00:00, 10101.43it/s]
# ✅ Configuration Fixed!
#
# --- STEP 4: Training YOLO11 ---
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/my_dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=waste_detection, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/waste_detection, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 854.4±288.7 MB/s, size: 25.4 KB)
# train: Scanning /kaggle/working/my_dataset/train/labels... 14225 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 14225/14225 1.4Kit/s 10.0s<0.0s
# train: New cache created: /kaggle/working/my_dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 348.0±295.3 MB/s, size: 14.2 KB)
# val: Scanning /kaggle/working/my_dataset/valid/labels... 2098 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2098/2098 1.2Kit/s 1.7s0.1s
# val: New cache created: /kaggle/working/my_dataset/valid/labels.cache
# Plotting labels to /kaggle/working/runs/waste_detection/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/waste_detection
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      5.51G      1.361      2.088      1.467          4        640: 100% ━━━━━━━━━━━━ 890/890 5.5it/s 2:40<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 3.7it/s 17.7s0.2s
#                    all       2098      18916      0.643      0.466      0.519      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      6.06G      1.368       1.64      1.477          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.3it/s 15.5s0.2s
#                    all       2098      18916      0.557       0.42      0.441      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      5.96G      1.438      1.659      1.525          6        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 3.6it/s 18.2s0.3s
#                    all       2098      18916      0.398      0.343      0.293      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      5.21G      1.472      1.661      1.561          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.8s0.2s
#                    all       2098      18916      0.597      0.408      0.448       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      5.84G      1.425      1.573      1.546         49        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.7s0.2s
#                    all       2098      18916      0.614      0.469      0.521      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      5.86G      1.401      1.503      1.517         20        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.636      0.473      0.541      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.12G      1.374       1.45      1.499          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.4it/s 15.0s0.2s
#                    all       2098      18916      0.666       0.47      0.547       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      6.11G      1.361      1.406      1.484         28        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.5s0.2s
#                    all       2098      18916      0.645      0.483      0.547      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.03G      1.346      1.382      1.476          5        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.6s0.2s
#                    all       2098      18916      0.672      0.502      0.579      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      7.33G      1.328      1.348      1.462          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.6s0.2s
#                    all       2098      18916      0.669      0.519      0.591      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      7.33G      1.338      1.332      1.455        276        640: 33% ━━━╸──────── 295/890 5.7it/s 51.6s<1:44

# %%
from ultralytics import YOLO

# Load the last checkpoint
model = YOLO("/kaggle/working/runs/waste_detection/weights/last.pt")

# Resume! (No need to set epochs, it remembers)
results = model.train(resume=True)
# Out:
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/my_dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/runs/waste_detection/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=waste_detection, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=/kaggle/working/runs/waste_detection/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/waste_detection, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 787.8±361.9 MB/s, size: 22.7 KB)
# train: Scanning /kaggle/working/my_dataset/train/labels.cache... 14225 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 14225/14225 19.0Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 272.1±139.5 MB/s, size: 11.6 KB)
# val: Scanning /kaggle/working/my_dataset/valid/labels.cache... 2098 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2098/2098 2.4Mit/s 0.0s0s
# Plotting labels to /kaggle/working/runs/waste_detection/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Resuming training /kaggle/working/runs/waste_detection/weights/last.pt from epoch 32 to 50 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/waste_detection
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      7.83G      1.159     0.9821      1.321          4        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:30<0.1s
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/multiprocessing/queues.py", line 239, in _feed
#     reader_close()
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 178, in close
#     self._close()
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 377, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.2s0.2s
#                    all       2098      18916       0.76      0.599      0.692      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      5.04G      1.179      1.044      1.351          1        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.2s0.2s
#                    all       2098      18916      0.751      0.603      0.691      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      5.04G      1.183      1.035      1.339          6        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.0s0.2s
#                    all       2098      18916      0.761      0.595      0.692      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      5.04G      1.182      1.021      1.333          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.744       0.61      0.697      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      5.04G      1.167      1.016      1.334         49        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.759       0.61      0.701      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      5.04G      1.164     0.9993      1.327         20        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.2s0.2s
#                    all       2098      18916      0.761      0.611      0.704      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      5.04G      1.156     0.9929      1.323          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.766       0.62      0.707      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      5.04G       1.16     0.9831      1.322         28        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:35<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.765      0.615      0.702      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      5.04G      1.155     0.9808      1.321          5        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.773      0.614      0.708      0.472
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      5.04G      1.164     0.9625      1.343          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.758      0.616      0.704      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.04G      1.152      0.946      1.339        125        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:31<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.766      0.611      0.703      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.04G      1.144     0.9291       1.33          1        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.758      0.619      0.705      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.04G      1.132     0.9097      1.325          3        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.761      0.616      0.703      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.04G      1.126     0.8975      1.319          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.769      0.615      0.704       0.47
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.04G      1.122     0.8791      1.312          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:32<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.766      0.618      0.705      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.04G      1.117     0.8726      1.309          2        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.0s0.2s
#                    all       2098      18916      0.767      0.617      0.705      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      5.04G       1.11     0.8649      1.306          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.772      0.616      0.706      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.04G      1.104     0.8617      1.305          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.2s0.2s
#                    all       2098      18916      0.776      0.612      0.706      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.04G      1.089     0.8382      1.292          1        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 13.9s0.2s
#                    all       2098      18916      0.777      0.613      0.706      0.474
#
# 19 epochs completed in 0.883 hours.
# Optimizer stripped from /kaggle/working/runs/waste_detection/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/waste_detection/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/waste_detection/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.0it/s 16.3s0.2s
#                    all       2098      18916      0.776      0.612      0.706      0.474
#          Biodegradable       1109      14962      0.755      0.518      0.625      0.368
#      Non-Biodegradable       1037       3954      0.798      0.706      0.786      0.579
# Speed: 0.2ms preprocess, 2.3ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /kaggle/working/runs/waste_detection

# %%
from ultralytics import YOLO

# 1. Load the weights you just finished training
# (This file contains all the knowledge from the first 50 epochs)
model = YOLO("/kaggle/working/runs/waste_detection/weights/last.pt")

print("🚀 Starting Fine-Tuning...")

# 2. Start a NEW training run
# We do NOT use 'resume=True'. We treat it as a new job starting with a smart brain.
results = model.train(
    data='/kaggle/working/my_dataset/data.yaml',  # Point to your dataset config
    epochs=50,                  # Train for 50 MORE epochs (Total will be ~100)
    imgsz=640,
    batch=16,
    project='/kaggle/working/runs',
    name='waste_detection_v2',  # Save to a new folder so we don't overwrite the old one
    save=True,
    exist_ok=True
)

# 3. Zip the new results
import shutil
from IPython.display import FileLink

print("\n📦 Zipping new results...")
shutil.make_archive('YOLO_Results_v2', 'zip', '/kaggle/working/runs/waste_detection_v2')
print("✅ Done! Download below:")
display(FileLink('YOLO_Results_v2.zip'))
# Out:
# 🚀 Starting Fine-Tuning...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/my_dataset/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/kaggle/working/runs/waste_detection/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=waste_detection_v2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/waste_detection_v2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 651.6±408.9 MB/s, size: 22.7 KB)
# train: Scanning /kaggle/working/my_dataset/train/labels.cache... 14225 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 14225/14225 17.9Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 206.9±46.9 MB/s, size: 11.6 KB)
# val: Scanning /kaggle/working/my_dataset/valid/labels.cache... 2098 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2098/2098 2.5Mit/s 0.0s0s
# Plotting labels to /kaggle/working/runs/waste_detection_v2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/waste_detection_v2
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      4.75G      1.117     0.9114      1.291          4        640: 100% ━━━━━━━━━━━━ 890/890 5.4it/s 2:43<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.2s0.2s
#                    all       2098      18916      0.752      0.611      0.696      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      6.13G      1.135     0.9491      1.312          1        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:37<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.5s0.2s
#                    all       2098      18916      0.746      0.603      0.681      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      6.13G      1.192      1.031      1.336          6        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.6s0.2s
#                    all       2098      18916      0.702      0.541      0.619      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      6.13G      1.244      1.126      1.374          2        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.8s0.2s
#                    all       2098      18916      0.706      0.535      0.615      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      6.14G      1.239      1.136      1.384         49        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.6s0.2s
#                    all       2098      18916      0.729      0.551      0.638      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      6.15G      1.239      1.127      1.378         20        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.715      0.556      0.638      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      6.15G      1.234      1.124      1.378          2        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.8s0.2s
#                    all       2098      18916      0.718      0.556      0.641      0.406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      6.15G      1.239      1.115      1.373         28        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.734      0.555      0.648      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      6.15G      1.232      1.111      1.379          5        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.734      0.576      0.661      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      6.15G      1.226      1.105       1.37          2        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.5s0.2s
#                    all       2098      18916      0.724      0.577      0.663      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      6.15G      1.236      1.108      1.374         53        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.7s0.2s
#                    all       2098      18916      0.712       0.56      0.644      0.411
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      6.15G      1.227      1.092      1.365          1        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.722      0.589      0.666      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      6.15G      1.214      1.075      1.356          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:35<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.763      0.582      0.673      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      6.15G        1.2      1.064      1.353          9        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.5s0.2s
#                    all       2098      18916      0.744      0.587      0.677       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      6.15G      1.204      1.049      1.351          3        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.5s0.2s
#                    all       2098      18916      0.744      0.587      0.674      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      6.15G       1.19      1.053      1.349          3        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.5s0.2s
#                    all       2098      18916      0.736      0.592      0.678      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      6.15G      1.203      1.046       1.35          2        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.757      0.594      0.682      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      6.15G      1.197      1.039      1.347         14        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.757      0.599      0.688      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      6.15G      1.181      1.024      1.335         46        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.745      0.602      0.687      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      6.15G      1.188       1.03      1.343          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:35<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916       0.75      0.602      0.691      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      6.15G       1.19      1.022      1.338          2        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.6s0.2s
#                    all       2098      18916      0.744      0.606      0.694      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      6.15G      1.186      1.013      1.335          2        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.6s0.2s
#                    all       2098      18916      0.759       0.61        0.7      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      6.15G      1.182      1.011      1.329          5        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.741      0.604      0.686      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      6.15G      1.169     0.9973      1.327          3        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.754      0.613      0.699      0.454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      6.15G      1.164     0.9916      1.323          3        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.753      0.616      0.699      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      6.15G      1.162     0.9773      1.318          2        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.771      0.621      0.709      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      6.15G      1.152     0.9717      1.317          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.763      0.625      0.712      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      6.15G       1.15     0.9685      1.313          7        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.774      0.608      0.702      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      6.15G      1.144     0.9601      1.312          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:35<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.763      0.624      0.709      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      6.15G       1.14     0.9483      1.307          8        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:35<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.2s0.2s
#                    all       2098      18916      0.758      0.623      0.707      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      6.15G      1.136     0.9468      1.307         32        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:34<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.766      0.623      0.711      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      6.15G      1.139     0.9412      1.305          8        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.773      0.624      0.713      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      6.15G      1.137     0.9436      1.306        201        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:35<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.782      0.618      0.714      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      6.15G      1.127     0.9282      1.297          9        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:35<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.764      0.629      0.716      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      6.15G      1.136     0.9259      1.299          1        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.4s0.2s
#                    all       2098      18916      0.767       0.63       0.72      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      6.15G      1.119     0.9138      1.294          4        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.762      0.633      0.717      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      6.15G      1.126     0.9045       1.29          8        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.769       0.63      0.719      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      6.15G      1.122     0.9098      1.292         51        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916      0.777      0.633      0.722      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      6.15G      1.107     0.8943      1.282          1        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916       0.78      0.631      0.723      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      6.15G      1.119     0.9033      1.286          1        640: 100% ━━━━━━━━━━━━ 890/890 5.7it/s 2:36<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.775      0.638      0.724      0.487
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.15G      1.112     0.8597      1.298          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.3s0.2s
#                    all       2098      18916       0.78      0.635      0.721      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      6.15G      1.098      0.829      1.286          6        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.772       0.63      0.717      0.482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      6.15G      1.096     0.8242      1.285          6        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:33<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.0s0.2s
#                    all       2098      18916      0.777      0.629      0.718      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      6.15G      1.087     0.8192      1.281          1        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.781      0.626      0.718      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      6.15G      1.079     0.8021      1.272          3        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.2s0.2s
#                    all       2098      18916      0.777      0.633      0.721      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      6.15G       1.07     0.7997      1.267          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.777      0.633      0.722      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      6.15G       1.06     0.7747      1.257          1        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.771      0.636      0.721      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      6.15G      1.059     0.7732      1.257          1        640: 100% ━━━━━━━━━━━━ 890/890 5.9it/s 2:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.778      0.633       0.72      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      6.15G      1.047     0.7616      1.255          2        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:32<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.7it/s 14.1s0.2s
#                    all       2098      18916      0.771      0.636      0.719      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      6.15G      1.053     0.7612      1.253          5        640: 100% ━━━━━━━━━━━━ 890/890 5.8it/s 2:32<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.5it/s 14.7s0.2s
#                    all       2098      18916      0.775      0.637       0.72      0.485
#
# 50 epochs completed in 2.355 hours.
# Optimizer stripped from /kaggle/working/runs/waste_detection_v2/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/waste_detection_v2/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/waste_detection_v2/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 66/66 4.0it/s 16.6s0.2s
#                    all       2098      18916      0.776      0.638      0.724      0.487
#          Biodegradable       1109      14962      0.735      0.555      0.642      0.381
#      Non-Biodegradable       1037       3954      0.816      0.721      0.806      0.594
# Speed: 0.2ms preprocess, 2.2ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /kaggle/working/runs/waste_detection_v2
#
# 📦 Zipping new results...
# ✅ Done! Download below:
# /kaggle/working/YOLO_Results_v2.zip

# %%
# ==========================================
# 5. ZIP RESULTS
# ==========================================
import shutil
from IPython.display import FileLink

print("\n--- STEP 5: Zipping Output ---")
output_folder = f"{PROJECT_DIR}/{NAME}"
zip_name = "YOLO_Results"
shutil.make_archive(zip_name, 'zip', output_folder)

print(f"✅ Zip created! Click below to download:")
display(FileLink(f"{zip_name}.zip"))
# Out:
# --- STEP 5: Zipping Output ---
# ✅ Zip created! Click below to download:
# /kaggle/working/YOLO_Results.zip

# %%
# !yolo export model=/content/best.pt format=tflite int8
